# %%
print("Hello, Berlin!")

# %%
arr=["hi","there"]
print(arr)
print(set(arr))

# %%
for i in range(10):
    print(i)

# %%
for i in range(2,10,3):
    print(i)

# %%
arr=["hi","there"]
for element in arr:
    print(element)

# %%
for index,element in enumerate(arr):
    print(index,element)

# %%
dict = {
    "name":"Harry",
    "lastname":"Hasenfuß",
    "title":"bug lover"
}
print(dict)

# %%
dict={}
dict["name"]="Tristan"
dict["lastname"]="Hasenfuß"
dict["name"]="bug lover"
dict.pop("name")
del

# %%
dict = {
    "name":"Harry",
    "lastname":"Hasenfuß",
    "title":"bug lover"
}

for index, (key,value) in enumerate(dict.items()):
    print(index, key,value)

# %%
something=True
while something==True:
    print(1)
    something=False

# %%
a=1
if a==1:
    print('yo!')
elif a==2:
    print('yo mai!')
else:
    pass

# %%
for i in range(10):
    print(i)
    if i==5:
        # or continue
        break

# %%
try:
    a=1/0
except:
    print('divide by zero')
finally:
    print('rin3l3m3n5')

# %%
raise Exception("really bad stuff happened")

# %%
def sum(a,b):
    pass
    return(a+b)

print(sum(10,1))
print(type(sum))
sum2=sum
print(sum2)

# %%
# OO: not recommended
class Classy:
    def __init__(self):
        self.value=10
    def show(self):
        return(self.value)

# %%
import glob

paths = glob.glob("*.*")
print(paths)

# %%
import requests
url = 'http://www.digbib.org/Johann_Wolfgang_von_Goethe_1749/Faust_I?textonly=1'
webtext = requests.get(url).text
print(type(webtext))
print (webtext)
# Out:
# <class 'str'>
# Johann Wolfgang von Goethe: Faust, Der Tragödie erster Teil
#
# * Quelle: http://NDAL8PCAG/www/digbib.org/Johann_Wolfgang_von_Goethe_1749/Faust_I
# * Erstellt am: 18.06.2018
# * DigBib.Org ist ein öffentliches Projekt. Bitte helfen Sie die Qualität der Texte zu verbessern: Falls Sie Fehler finden bitte bei DigBib.Org melden.
#
#
# Zueignung.
#
# Ihr naht euch wieder, schwankende Gestalten,
# Die früh sich einst dem trüben Blick gezeigt.
# Versuch ich wohl, euch diesmal festzuhalten?
# Fühl ich mein Herz noch jenem Wahn geneigt?
# Ihr drängt euch zu!  nun gut, so mögt ihr walten,
# Wie ihr aus Dunst und Nebel um mich steigt;
# Mein Busen fühlt sich jugendlich erschüttert
# Vom Zauberhauch, der euren Zug umwittert.
#
# Ihr bringt mit euch die Bilder froher Tage,
# Und manche liebe Schatten steigen auf;
# Gleich einer alten, halbverklungnen Sage
# Kommt erste Lieb und Freundschaft mit herauf;
# Der Schmerz wird neu, es wiederholt die Klage
# ...

# %%
vocabulary=set(webtext)

import string

webtext_clean=webtext.replace("\n"," ")
webtext_clean=webtext_clean.replace(".","")
webtext_clean=webtext_clean.replace("!","")
webtext_clean=webtext_clean.replace("?","")
webtext_clean=webtext_clean.replace(","," ")

vocab=webtext_clean.split(" ")
vocab=set(vocab)
print(type(vocab))
print(len(vocab))
print(vocab)
# Out:
# <class 'str'>
# <class 'set'>
# 7577
# ...
